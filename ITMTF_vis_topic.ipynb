# %%
#import warnings
#warnings.filterwarnings('ignore')

from IPython.display import HTML
HTML('''<script>
 $('div.output_stderr').hide();
''')

# %run load_helper.ipynb


import pyLDAvis
import pyLDAvis.gensim  


# ##################################################
# Name the model to vis
#
#        baselines = ["10topics", "15topics", "20topics", "25topics", "30topics"]
#
#        or for an iteration
#        myiteration1
#
# once it loads, click or hover a circle to see the top terms
# NOTE: this is an old library, and my through warning on depracated calls
#       it is save to ignore those
#
# unfortunately, you can only have one open at a time
# if you want to do a side by side look, have to open this notebook twice
#
# ##################################################
modelname = "Testcleanupclassic2"


file_name = save_path + modelname + ".sav"
model = LdaModel.load(file_name)

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(model, corpus, dictionary)
vis
# Out:
# C:\Users\mlbernardoni\anaconda3\envs\gensim\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Number of time slices with docs: 123
# Number of time slices: 123
# Number of time vocab: 12517
# Size of doctokens: 2673
# Number of documents: 2673
# Number of unique tokens: 12517
# Pearsons correlation: 12517
# Pearsons/Granger correlation: 12517
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 0      0.020270  0.000733       1        1  42.389035
# 1      0.062288  0.048082       2        1  18.937696
# 4     -0.163975 -0.156623       3        1  13.702851
# 3     -0.118618  0.010758       4        1   9.208850
# ...
